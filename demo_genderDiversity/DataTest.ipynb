# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("uiuc_demographics_2005_15.csv")

# %%
df
# Out:
#         Fall  Term Code College  Dept.  Degree  Major Code  \
# 0     2015.0   120158.0     KP   227.0     BS       5163.0
# 1     2015.0   120158.0     KP   227.0     BS       5163.0
# 2     2015.0   120158.0     KP   227.0  MENGR       1211.0
# 3     2015.0   120158.0     KP   227.0     BS       5163.0
# 4     2015.0   120158.0     KP   227.0     MS       5163.0
# 5     2015.0   120158.0     KP   227.0    PHD       5163.0
# 6     2015.0   120158.0     KP   227.0   NDEG         67.0
# 7     2015.0   120158.0     KM   230.0    MBA       9875.0
# 8     2015.0   120158.0     KM   230.0    MBA       9875.0
# 9     2015.0   120158.0     KM   230.0    MBA       9875.0
# 10    2015.0   120158.0     KT   238.0    PHD        279.0
# 11    2015.0   120158.0     KT   238.0    PHD       5202.0
# 12    2015.0   120158.0     KV   241.0  BALAS        340.0
# 13    2015.0   120158.0     KV   241.0  BALAS        340.0
# 14    2015.0   120158.0     KV   241.0  BSLAS       5348.0
# ...

# %%
df["% Female"] = df["Female"] / df["Total"]

# %%
df
# Out:
#         Fall  Term Code College  Dept.  Degree  Major Code  \
# 0     2015.0   120158.0     KP   227.0     BS       5163.0
# 1     2015.0   120158.0     KP   227.0     BS       5163.0
# 2     2015.0   120158.0     KP   227.0  MENGR       1211.0
# 3     2015.0   120158.0     KP   227.0     BS       5163.0
# 4     2015.0   120158.0     KP   227.0     MS       5163.0
# 5     2015.0   120158.0     KP   227.0    PHD       5163.0
# 6     2015.0   120158.0     KP   227.0   NDEG         67.0
# 7     2015.0   120158.0     KM   230.0    MBA       9875.0
# 8     2015.0   120158.0     KM   230.0    MBA       9875.0
# 9     2015.0   120158.0     KM   230.0    MBA       9875.0
# 10    2015.0   120158.0     KT   238.0    PHD        279.0
# 11    2015.0   120158.0     KT   238.0    PHD       5202.0
# 12    2015.0   120158.0     KV   241.0  BALAS        340.0
# 13    2015.0   120158.0     KV   241.0  BALAS        340.0
# 14    2015.0   120158.0     KV   241.0  BSLAS       5348.0
# ...

# %%
group_majors = df.groupby("Major Name")

# %%
group_majors

# %%
group_majors.describe()
# Out:
#                                         % Female  Dept.         Fall  \
# Major Name
# Accountancy                     count  71.000000   71.0    71.000000
#                                 mean    0.504214  346.0  2009.380282
#                                 std     0.213181    0.0     3.199849
#                                 min     0.000000  346.0  2005.000000
#                                 25%     0.421554  346.0  2007.000000
#                                 50%     0.459893  346.0  2009.000000
#                                 75%     0.537088  346.0  2012.000000
#                                 max     1.000000  346.0  2015.000000
# Actuarial Science               count  24.000000   24.0    24.000000
#                                 mean    0.440671  257.0  2010.208333
#                                 std     0.191762    0.0     3.175712
#                                 min     0.000000  257.0  2005.000000
# ...

# %%
df_cs = group_majors.get_group("Advertising")
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-9-f48797eeb059> in <module>()
# ----> 1 df_cs = group_majors.get_group("Advertising")
#
# C:\Users\Nathan\Miniconda2\lib\site-packages\pandas\core\groupby.pyc in get_group(self, name, obj)
#     616         inds = self._get_index(name)
#     617         if not len(inds):
# --> 618             raise KeyError(name)
#     619
#     620         return obj.take(inds, axis=self.axis, convert=False)
#
# KeyError: 'Advertising'

# %%
df_cs = group_majors.get_group("Advertising ")

# %%
df_cs
# Out:
#       % Female Academic Program Code College Conc. Code Conc. Name Degree  \
# 134   0.851852            10KS0277MS     KT                           MS
# 135   0.676157            10KT0277BS     KT                           BS
# 829   0.833333            10KS0277MS     KT                           MS
# 830   0.692573            10KT0277BS     KT                           BS
# 1510  0.750000            10KS0277MS     KT                           MS
# 1511  0.720207            10KT0277BS     KT                           BS
# 2213  0.710526            10KS0277MS     KT                           MS
# 2214  0.719735            10KT0277BS     KT                           BS
# 2906  0.766667            10KS0277MS     KT                           MS
# 2907  0.691693            10KT0277BS     KT                           BS
# 3607  1.000000            10KS0277MS     KT                           MS
# 3608  0.690802            10KT0277BS     KT                           BS
# ...

# %%
df_cs = df_cs[ df_cs["Degree"] == "BS "]
df_cs = df_cs[ df_cs["Fall"] == 2015.0 ]

# %%
# Out:
#      % Female Academic Program Code College Conc. Code Conc. Name Degree  \
# 135  0.676157            10KT0277BS     KT                           BS
#
#      Dept.    Fall  Female  Major Code   Male  Term Code  Total  Unknown
# 135  408.0  2015.0   380.0       277.0  182.0   120158.0  562.0      0.0

# %%
df_cs = group_majors.get_group("Advertising ")
df_cs = df_cs[ df_cs["Degree"] == "BS "]
g2 = df_cs.groupby("Fall")
g2.sum()
# Out:
#         % Female  Dept.  Female  Major Code   Male  Term Code  Total  Unknown
# Fall
# 2005.0  0.748936  408.0   176.0       277.0   59.0   120058.0  235.0      0.0
# 2006.0  0.733728  408.0   248.0       277.0   90.0   120068.0  338.0      0.0
# 2007.0  0.747191  408.0   266.0       277.0   90.0   120078.0  356.0      0.0
# 2008.0  0.704388  408.0   305.0       277.0  128.0   120088.0  433.0      0.0
# 2009.0  0.664319  408.0   283.0       277.0  142.0   120098.0  426.0      1.0
# 2010.0  0.690802  408.0   353.0       277.0  158.0   120108.0  511.0      0.0
# 2011.0  0.691693  408.0   433.0       277.0  193.0   120118.0  626.0      0.0
# 2012.0  0.719735  408.0   434.0       277.0  169.0   120128.0  603.0      0.0
# 2013.0  0.720207  408.0   417.0       277.0  162.0   120138.0  579.0      0.0
# 2014.0  0.692573  408.0   401.0       277.0  178.0   120148.0  579.0      0.0
# 2015.0  0.676157  408.0   380.0       277.0  182.0   120158.0  562.0      0.0
