# %%
import pandas as pd
import numpy as np
frames = []
for year in range(1925,2013):
  
    df = pd.read_csv("bronzeTablet_1925_2013.csv", names=["Year", "Name", "Something"])
    frames.append( df )

df = pd.concat(frames, ignore_index=True)

# %%
df
# Out:
#          Year                      Name Something
# 0        1925        Claron Dale Barber       NaN
# 1        1925       Francis James Benda       NaN
# 2        1925          Philip Berkowitz       NaN
# 3        1925  William Herbert Clingman       NaN
# 4        1925   Roman Anthony Jascoviak       NaN
# 5        1925    William Dwight Lansing       NaN
# 6        1925       Essie Adele Morrell       NaN
# 7        1925      Waldo George Mueller       NaN
# 8        1925     Rudolph Earl Peterson       NaN
# 9        1925       Gilbert Jay Roberts       NaN
# 10       1925        Carl Emil Roessler       NaN
# 11       1925     George Heywood Vernon       NaN
# 12       1925       Mary Frances Waters       NaN
# 13       1925       Le Roy Richard Weis       NaN
# 14       1926        Robert Verne Baker       NaN
# 15       1926    Louise Alice Brumbaugh       NaN
# 16       1926    Martin Paul Catherwood       NaN
# 17       1926      Blanche Marie Colvin       NaN
# ...

# %%
test = df.pivot_table(index="Year")
test
# Out:
# DataErrorTraceback (most recent call last)
# <ipython-input-17-30ba1dd9a217> in <module>()
# ----> 1 test = df.pivot_table(index="Year")
#       2 test
#
# C:\Users\Nathan\Miniconda2\lib\site-packages\pandas\tools\pivot.pyc in pivot_table(data, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name)
#     125
#     126     grouped = data.groupby(keys)
# --> 127     agged = grouped.agg(aggfunc)
#     128
#     129     table = agged
#
# C:\Users\Nathan\Miniconda2\lib\site-packages\pandas\core\groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    3702     @Appender(SelectionMixin._agg_doc)
#    3703     def aggregate(self, arg, *args, **kwargs):
# -> 3704         return super(DataFrameGroupBy, self).aggregate(arg, *args, **kwargs)
#    3705
#    3706     agg = aggregate
#
# C:\Users\Nathan\Miniconda2\lib\site-packages\pandas\core\groupby.pyc in aggregate(self, arg, *args, **kwargs)
#    3191
#    3192         _level = kwargs.pop('_level', None)
# ...

# %%
def getProbF(d):
    # d is each record in our DataFrame
    # Example: d["Full Name"] will return each person's full name
   
    # ... your code ...
   
    # Return the value that should be inserted into the row:
    return 0.5

def getProbM(d):
    # d is each record in our DataFrame
    # Example: d["Full Name"] will return each person's full name
   
    # ... your code ...
   
    # Return the value that should be inserted into the row:
    return 0.5

df_bronzeTabletNames["pFemale"] = df_bronzeTabletNames.apply(getProbF, axis=1)
# Out:
# NameErrorTraceback (most recent call last)
# <ipython-input-5-5879f129467e> in <module>()
#      17     return 0.5
#      18
# ---> 19 df_bronzeTabletNames["pFemale"] = df_bronzeTabletNames.apply(getProbF, axis=1)
#
# NameError: name 'df_bronzeTabletNames' is not defined

# %%
df_tabletest = pd.DataFrame(index = list(range(1925,2013)),columns =["Unknown Name","Unisex Name","Female Name","Male Name","%Male Names(of known names)","%Female Names(of known names)"])
df_tabletest
# Out:
#      Unknown Name Unisex Name Female Name Male Name  \
# 1925          NaN         NaN         NaN       NaN
# 1926          NaN         NaN         NaN       NaN
# 1927          NaN         NaN         NaN       NaN
# 1928          NaN         NaN         NaN       NaN
# 1929          NaN         NaN         NaN       NaN
# 1930          NaN         NaN         NaN       NaN
# 1931          NaN         NaN         NaN       NaN
# 1932          NaN         NaN         NaN       NaN
# 1933          NaN         NaN         NaN       NaN
# 1934          NaN         NaN         NaN       NaN
# 1935          NaN         NaN         NaN       NaN
# 1936          NaN         NaN         NaN       NaN
# 1937          NaN         NaN         NaN       NaN
# 1938          NaN         NaN         NaN       NaN
# 1939          NaN         NaN         NaN       NaN
# 1940          NaN         NaN         NaN       NaN
# 1941          NaN         NaN         NaN       NaN
# ...
